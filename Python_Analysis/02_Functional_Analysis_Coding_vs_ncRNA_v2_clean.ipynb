# %% [markdown]
# # Análisis funcional comparativo: Coding-only vs Coding+ncRNA
#
# ## Objetivo general
#
# Evaluar si la incorporación de genes no codificantes modifica la interpretación biológica de los cambios asociados a la lesión medular.
#
# ## Ensayos incluidos
#
# 1. Expresión diferencial (DEGs).
# 2. Enriquecimiento funcional (GO, Reactome, KEGG).
# 3. Actividad de vías mediante PROGENy.
# 4. Identificación de ncRNAs y pri-miRNAs relevantes.
#
# Este notebook asume que los objetos AnnData ya han sido integrados, anotados y evaluados estructuralmente.

# %% [markdown]
# ## Librerías

# %%
import importlib.util

packages = {
    "scanpy": "scanpy",
    "pandas": "pandas",
    "numpy": "numpy",
    "seaborn": "seaborn",
    "matplotlib": "matplotlib",
    "gseapy": "gseapy",
    "decoupler": "decoupler",
    "matplotlib_venn": "matplotlib-venn"
}

for import_name, pip_name in packages.items():
    if importlib.util.find_spec(import_name) is not None:
        print(f"{import_name}: instalado")
    else:
        print(f"{import_name}: NO instalado → instalar con pip install {pip_name}")
# Out:
# scanpy: instalado
# pandas: instalado
# numpy: instalado
# seaborn: instalado
# matplotlib: instalado
# gseapy: NO instalado → instalar con pip install gseapy
# decoupler: NO instalado → instalar con pip install decoupler
# matplotlib_venn: NO instalado → instalar con pip install matplotlib-venn

# %%
# %pip install gseapy
# Out:
# Collecting gseapy
#   Downloading gseapy-1.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.13.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gseapy) (2.4.6)
# Requirement already satisfied: scipy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gseapy) (1.17.1)
# Requirement already satisfied: pandas in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gseapy) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gseapy) (3.10.9)
# Requirement already satisfied: requests in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gseapy) (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (25.0)
# Requirement already satisfied: pillow>=8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=2.2->gseapy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->gseapy) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->gseapy) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->gseapy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->gseapy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->gseapy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->gseapy) (2026.2.25)
# Downloading gseapy-1.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (634 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.7/634.7 kB 26.4 MB/s  0:00:00
# Installing collected packages: gseapy
# Successfully installed gseapy-1.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install decoupler
# Out:
# Collecting decoupler
#   Downloading decoupler-2.1.6-py3-none-any.whl.metadata (7.2 kB)
# Collecting adjusttext (from decoupler)
#   Downloading adjusttext-1.4.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: anndata in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (0.12.16)
# Collecting docrep (from decoupler)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting marsilea (from decoupler)
#   Downloading marsilea-0.6.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: numba in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (0.65.1)
# Requirement already satisfied: requests in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (2.32.5)
# Requirement already satisfied: scipy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (1.17.1)
# Requirement already satisfied: session-info2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (0.4.1)
# Requirement already satisfied: tqdm in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from decoupler) (4.67.3)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from adjusttext->decoupler) (2.4.6)
# Requirement already satisfied: matplotlib in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from adjusttext->decoupler) (3.10.9)
# Requirement already satisfied: array-api-compat>=1.7.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (1.14.0)
# Requirement already satisfied: h5py>=3.8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (3.16.0)
# Requirement already satisfied: legacy-api-wrap in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (1.5)
# Requirement already satisfied: natsort in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (25.0)
# Requirement already satisfied: pandas!=2.1.2,<3,>=2.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (2.3.3)
# Requirement already satisfied: scverse-misc>=0.0.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (0.0.7)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anndata->decoupler) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata->decoupler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata->decoupler) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata->decoupler) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.2,<3,>=2.1.0->anndata->decoupler) (1.17.0)
# Requirement already satisfied: typing-extensions in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from scverse-misc>=0.0.3->anndata->decoupler) (4.15.0)
# Requirement already satisfied: donfig>=0.8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata->decoupler) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata->decoupler) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from zarr!=3.0.*,>=2.18.7->anndata->decoupler) (0.16.5)
# Requirement already satisfied: pyyaml in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata->decoupler) (6.0.3)
# Collecting legendkit (from marsilea->decoupler)
#   Downloading legendkit-0.5.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: platformdirs in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from marsilea->decoupler) (4.9.4)
# Requirement already satisfied: seaborn in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from marsilea->decoupler) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->adjusttext->decoupler) (3.3.2)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from numba->decoupler) (0.47.0)
# Collecting pyarrow>=10.0.1 (from pandas[parquet]->marsilea->decoupler)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->decoupler) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->decoupler) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->decoupler) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->decoupler) (2026.2.25)
# Downloading decoupler-2.1.6-py3-none-any.whl (121 kB)
# Downloading adjusttext-1.4.0-py3-none-any.whl (13 kB)
# Downloading marsilea-0.6.2-py3-none-any.whl (87 kB)
# Downloading legendkit-0.5.0-py3-none-any.whl (35 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 94.6 MB/s  0:00:00m eta 0:00:01
# Building wheels for collected packages: docrep
#   Building wheel for docrep (pyproject.toml) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19971 sha256=f6617f2476cebb9bd05cdccffdd703f70cffc9fd333471d100503bfa38d97d69
#   Stored in directory: /teamspace/studios/this_studio/.cache/pip/wheels/d6/19/ee/0a6a1793d91c449563b49ccab57ce52da3e6fab7614836bd8c
# Successfully built docrep
# Installing collected packages: pyarrow, docrep, legendkit, adjusttext, marsilea, decoupler
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [decoupler]/6 [decoupler]
# Successfully installed adjusttext-1.4.0 decoupler-2.1.6 docrep-0.3.2 legendkit-0.5.0 marsilea-0.6.2 pyarrow-24.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib-venn
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.2.tar.gz (40 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib-venn) (3.10.9)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib-venn) (2.4.6)
# Requirement already satisfied: scipy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib-venn) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45388 sha256=afaf77a8ede0c831b5afe77158668d3a4406b072ccce117644cec2db42909be4
#   Stored in directory: /teamspace/studios/this_studio/.cache/pip/wheels/c2/47/0c/f014c55a1cfd56dce41a1cafd23e3c590652b5e71330cc181c
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import scanpy as sc
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import gseapy as gp
import decoupler as dc

from matplotlib_venn import venn2

# %% [markdown]
# ## Carga de datos y emparejamiento de células

# %%
adata_coding = sc.read_h5ad("adata_coding_integrated.h5ad")
adata_ncrna = sc.read_h5ad("adata_ncrna_integrated.h5ad")

# %%
# Structural summary of the loaded objects
print("Coding-only:", adata_coding)
print("Coding+ncRNA:", adata_ncrna)

print("Dimensions:")
print(f"coding:       {adata_coding.n_obs:,} cells x {adata_coding.n_vars:,} genes")
print(f"coding+ncRNA: {adata_ncrna.n_obs:,} cells x {adata_ncrna.n_vars:,} genes")
# Out:
# Coding-only: AnnData object with n_obs × n_vars = 43570 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Coding+ncRNA: AnnData object with n_obs × n_vars = 39966 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Dimensions:
# coding:       43,570 cells x 30,795 genes
# coding+ncRNA: 39,966 cells x 47,611 genes

# %%
print("Condition - coding")
print(adata_coding.obs["Condition"].value_counts())

print("Condition - coding+ncRNA")
print(adata_ncrna.obs["Condition"].value_counts())

print("Cell type - coding")
print(adata_coding.obs["annotation"].value_counts())

print("Cell type - coding+ncRNA")
print(adata_ncrna.obs["annotation"].value_counts())
# Out:
# Condition - coding
# Condition
# omt        26166
# tumor      12460
# control     4944
# Name: count, dtype: int64
# Condition - coding+ncRNA
# Condition
# omt        24639
# tumor      10599
# control     4728
# Name: count, dtype: int64
# Cell type - coding
# annotation
# Epithelial        17258
# CD8T              10102
# CD8Tex             9956
# Mono/Macro         3092
# B                  1354
# Fibroblasts         808
# Tprolif             411
# Malignant           274
# Plasma              252
# Endothelial          61
# Myofibroblasts        2
# Name: count, dtype: int64
# Cell type - coding+ncRNA
# annotation
# Epithelial        17061
# CD8Tex             9037
# CD8T               6309
# Mono/Macro         3973
# B                  1383
# Fibroblasts         726
# Tprolif             498
# Malignant           473
# Plasma              443
# Endothelial          61
# Myofibroblasts        2
# Name: count, dtype: int64

# %%
# Find shared cells between both AnnData objects
common_cells = adata_coding.obs_names.intersection(adata_ncrna.obs_names)

print(f"Cells in coding:       {adata_coding.n_obs:,}")
print(f"Cells in coding+ncRNA: {adata_ncrna.n_obs:,}")
print(f"Common cells:         {len(common_cells):,}")

adata_coding_common = adata_coding[common_cells, :].copy()
adata_ncrna_common = adata_ncrna[common_cells, :].copy()

# To reorder the ncrna object to follow the same order as coding
adata_ncrna_common = adata_ncrna_common[adata_coding_common.obs_names, :].copy()

print("After pairing:")
print("coding_common:", adata_coding_common)
print("ncrna_common:", adata_ncrna_common)
# Out:
# Cells in coding:       43,570
# Cells in coding+ncRNA: 39,966
# Common cells:         39,823
# After pairing:
# coding_common: AnnData object with n_obs × n_vars = 39823 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# ncrna_common: AnnData object with n_obs × n_vars = 39823 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
# Check that the metadata match after pairing
metadata_cols = ["Sample", "Condition", "annotation"]
metadata_cols = [c for c in metadata_cols if c in adata_coding_common.obs.columns and c in adata_ncrna_common.obs.columns]

for col in metadata_cols:
    same = (adata_coding_common.obs[col].astype(str).values == adata_ncrna_common.obs[col].astype(str).values).all()
    print(f"{col}: {'OK' if same else 'Check'}")

print("Common composition per condition:")
print(adata_coding_common.obs["Condition"].value_counts())

print("Common composition per cell type:")
print(adata_coding_common.obs["annotation"].value_counts())
# Out:
# Sample: OK
# Condition: OK
# annotation: Check
# Common composition per condition:
# Condition
# omt        24600
# tumor      10507
# control     4716
# Name: count, dtype: int64
# Common composition per cell type:
# annotation
# Epithelial        14432
# CD8Tex             9805
# CD8T               9767
# Mono/Macro         2908
# B                  1326
# Fibroblasts         680
# Tprolif             395
# Malignant           239
# Plasma              212
# Endothelial          57
# Myofibroblasts        2
# Name: count, dtype: int64

# %% [markdown]
# # Ensayo 1. Expresión diferencial
#
# ## Objetivo
#
# Identificar genes diferencialmente expresados entre condiciones dentro de cada tipo celular.

# %%
adata_coding
# Out:
# AnnData object with n_obs × n_vars = 43570 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
adata_ncrna
# Out:
# AnnData object with n_obs × n_vars = 39966 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
celltypes_to_analyze = ["Epithelial", "CD8Tex", "Mono/Macro"]

print("Available cell types:")
print(adata_coding_common.obs["annotation"].value_counts())

print(f"Selected cell types: {celltypes_to_analyze}")
# Out:
# Available cell types:
# annotation
# Epithelial        14432
# CD8Tex             9805
# CD8T               9767
# Mono/Macro         2908
# B                  1326
# Fibroblasts         680
# Tprolif             395
# Malignant           239
# Plasma              212
# Endothelial          57
# Myofibroblasts        2
# Name: count, dtype: int64
# Selected cell types: ['Epithelial', 'CD8Tex', 'Mono/Macro']

# %%
# Function for runming the DEG by celltype
def run_deg_by_celltype(adata, celltype, group, layer=None):
    'Ejecuta rank_genes_groups dentro de un único tipo celular.'
    adata_ct = adata[adata.obs["annotation"] == celltype, :].copy()
    
    print(adata_ct)
    print("Cells per condition:")
    print(adata_ct.obs["Condition"].value_counts())
    
    if adata_ct.n_obs == 0:
        raise ValueError(f"There are no cell annotated as {celltype!r}.")
    
    if group not in adata_ct.obs["Condition"].astype(str).unique():
        raise ValueError(f"The group {group!r} is not present in Condition for {celltype!r}.")
    
    sc.tl.rank_genes_groups(
        adata_ct,
        groupby="Condition",
        groups=[group],
        reference="rest",
        method="wilcoxon",
        layer=layer,
        use_raw=False
    )
    
    deg = sc.get.rank_genes_groups_df(adata_ct, group=group)
    return adata_ct, deg

# %% [markdown]
# Coding

# %%
deg_results_coding = {}
adata_ct_results_coding = {}

for celltype in celltypes_to_analyze:
    print(f"\n==============================")
    print(f"Running DEG for: {celltype}")
    print(f"==============================")
    
    adata_ct, deg = run_deg_by_celltype(
        adata_coding_common,
        celltype=celltype,
        group="tumor",
        layer="logcounts"
    )
    
    adata_ct_results_coding[celltype] = adata_ct
    deg_results_coding[celltype] = deg
# Out:
# ==============================
# Running DEG for: Epithelial
# ==============================
# AnnData object with n_obs × n_vars = 14432 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        8017
# tumor      6044
# control     371
# Name: count, dtype: int64
#
# ==============================
# Running DEG for: CD8Tex
# ==============================
# AnnData object with n_obs × n_vars = 9805 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        5787
# control    2671
# tumor      1347
# Name: count, dtype: int64
#
# ==============================
# Running DEG for: Mono/Macro
# ==============================
# AnnData object with n_obs × n_vars = 2908 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        2379
# tumor       266
# control     263
# Name: count, dtype: int64

# %%
deg_results_coding["Epithelial"].head(20)
# Out:
#      names     scores  logfoldchanges  pvals  pvals_adj
# 0    MEIS2  73.992928        6.574618    0.0        0.0
# 1   CDKN2A  64.868767        4.028030    0.0        0.0
# 2     MUC1  61.211266        2.373459    0.0        0.0
# 3     BST2  60.781029        3.707051    0.0        0.0
# 4   MPPED2  60.741425        7.726506    0.0        0.0
# 5   NDUFB9  58.356953        2.343813    0.0        0.0
# 6     PTK2  56.805817        1.761975    0.0        0.0
# 7    RACK1  56.178528        2.050489    0.0        0.0
# 8     CD47  55.923969        1.792646    0.0        0.0
# 9     CANX  54.936413        1.764437    0.0        0.0
# 10      C3  54.358276        3.098759    0.0        0.0
# 11  SERBP1  54.198933        1.850296    0.0        0.0
# 12   TMED9  53.678062        2.294504    0.0        0.0
# 13   NR6A1  53.536560        2.747428    0.0        0.0
# 14     TXN  53.330078        2.149903    0.0        0.0
# 15  MRPS21  52.677914        2.036858    0.0        0.0
# 16  ATP1B1  52.244377        2.483408    0.0        0.0
# 17    ASS1  52.243248        2.493868    0.0        0.0
# 18  WDR45B  52.158688        1.795727    0.0        0.0
# 19   VEGFA  51.461758        2.697070    0.0        0.0

# %%
sc.pl.rank_genes_groups(adata_ct_results_coding["Epithelial"], n_genes=20, show=True)

# %%
deg_results_coding["CD8Tex"].head(20)
# Out:
#       names     scores  logfoldchanges          pvals      pvals_adj
# 0    IFI44L  31.388233        3.177913  2.928623e-216  9.018693e-212
# 1     IFI44  27.720894        2.361875  3.910334e-169  6.020937e-165
# 2      RBPJ  25.525665        1.627789  1.023116e-143  6.301371e-140
# 3      IFI6  25.465673        2.146708  4.733827e-143  2.429637e-139
# 4       MX1  25.337870        2.015588  1.222645e-141  5.378764e-138
# 5    HSPA1B  24.937540        1.745062  2.915166e-137  9.974726e-134
# 6    FNDC3B  24.344374        1.532508  6.650059e-131  1.706571e-127
# 7    SRGAP3  24.302341        1.872418  1.851696e-130  4.386383e-127
# 8     ISG15  23.954557        1.993818  8.283052e-127  1.594229e-123
# 9     IFI27  23.886108        3.781637  4.270797e-126  7.736423e-123
# 10     PVT1  23.877642        1.634631  5.229788e-126  8.947295e-123
# 11     FUT8  23.761435        1.497588  8.369770e-125  1.356563e-121
# 12     CAPG  23.373323        2.514076  7.984075e-121  1.117589e-117
# 13   PLSCR1  23.342449        1.645064  1.644341e-120  2.201630e-117
# 14  EIF2AK2  22.993944        1.454194  5.359114e-117  6.601357e-114
# 15  SPATS2L  22.819727        1.807709  2.921229e-115  3.459971e-112
# 16   EPSTI1  22.429243        1.584675  2.040834e-111  2.327684e-108
# 17      PKM  22.396238        1.508580  4.282505e-111  4.709991e-108
# 18    RPS20  22.301516        1.084385  3.571902e-110  3.792990e-107
# 19    MYO1E  22.237835        2.141312  1.479240e-109  1.518440e-106

# %%
sc.pl.rank_genes_groups(adata_ct_results_coding["CD8Tex"], n_genes=20, show=True)

# %%
deg_results_coding["Mono/Macro"].head(20)
# Out:
#          names     scores  logfoldchanges         pvals     pvals_adj
# 0         SPP1  19.757450        4.703119  6.921468e-87  2.131466e-82
# 1         ENO1  17.819099        1.715360  5.023805e-71  5.156936e-67
# 2         TPI1  17.130449        1.773280  8.797178e-66  3.386364e-62
# 3     C15orf48  16.373535        2.614496  2.955335e-60  1.011217e-56
# 4        GAPDH  16.152197        1.520109  1.095890e-58  3.374794e-55
# 5         LDHA  16.116531        1.931695  1.952632e-58  5.010942e-55
# 6          PKM  15.993834        1.447030  1.410749e-57  3.341847e-54
# 7          MIF  15.950624        1.917552  2.820673e-57  6.204472e-54
# 8        IL4I1  15.167048        2.544630  5.844737e-52  9.999372e-49
# 9        ADAM8  14.824082        2.119120  1.023694e-49  1.576232e-46
# 10    MTRNR2L8  14.544171        1.587693  6.359673e-48  8.359041e-45
# 11       BCAT1  14.025068        1.701792  1.095061e-44  1.162842e-41
# 12         VIM  13.977222        1.160300  2.147040e-44  2.132841e-41
# 13  AC025580.2  13.405908        2.447174  5.583589e-41  4.912760e-38
# 14       SNX10  13.369823        1.629099  9.075744e-41  7.763542e-38
# 15       BNIP3  13.258769        3.151016  4.014289e-40  3.253159e-37
# 16        ST14  13.126839        1.745928  2.311034e-39  1.824828e-36
# 17      TMEM51  13.105732        1.605391  3.053033e-39  2.350454e-36
# 18       ERO1A  13.101135        1.873551  3.243708e-39  2.436342e-36
# 19        ATF5  12.962578        2.034526  1.994322e-38  1.428259e-35

# %%
sc.pl.rank_genes_groups(adata_ct_results_coding["Mono/Macro"], n_genes=20, show=True)

# %% [markdown]
# Coding + Non Coding

# %%
deg_results_ncrna = {}
adata_ct_results_ncrna = {}

for celltype in celltypes_to_analyze:
    print(f"\n==============================")
    print(f"Running DEG for: {celltype}")
    print(f"==============================")
    
    adata_ct, deg = run_deg_by_celltype(
        adata_ncrna_common,
        celltype=celltype,
        group="tumor",
        layer="logcounts"
    )
    
    adata_ct_results_ncrna[celltype] = adata_ct
    deg_results_ncrna[celltype] = deg
# Out:
# ==============================
# Running DEG for: Epithelial
# ==============================
# AnnData object with n_obs × n_vars = 16959 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        9064
# tumor      7521
# control     374
# Name: count, dtype: int64
#
# ==============================
# Running DEG for: CD8Tex
# ==============================
# AnnData object with n_obs × n_vars = 9031 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        5281
# control    2690
# tumor      1060
# Name: count, dtype: int64
#
# ==============================
# Running DEG for: Mono/Macro
# ==============================
# AnnData object with n_obs × n_vars = 3970 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Cells per condition:
# Condition
# omt        3087
# tumor       591
# control     292
# Name: count, dtype: int64

# %%
deg_results_ncrna["Epithelial"].head(20)
# Out:
#               names     scores  logfoldchanges  pvals  pvals_adj
# 0             MEIS2  84.639282        6.512343    0.0        0.0
# 1            CDKN2A  77.112755        4.288149    0.0        0.0
# 2   ENSG00000293253  70.979187        6.193414    0.0        0.0
# 3              BST2  70.530098        3.721334    0.0        0.0
# 4            MPPED2  68.636055        7.645487    0.0        0.0
# 5           MT-RNR1  66.973854        1.392633    0.0        0.0
# 6            NDUFB9  66.789925        2.298074    0.0        0.0
# 7                C3  65.663750        3.328271    0.0        0.0
# 8              PTK2  65.428207        1.723560    0.0        0.0
# 9            SERBP1  63.774982        1.871735    0.0        0.0
# 10             RHEX  63.157890        2.570262    0.0        0.0
# 11            NR6A1  62.417500        2.764602    0.0        0.0
# 12           MRPS21  61.329559        2.012456    0.0        0.0
# 13           ATP1B1  61.250355        2.270820    0.0        0.0
# 14            DANT2  60.750137        2.183956    0.0        0.0
# 15             CD47  60.642315        1.701070    0.0        0.0
# 16             CANX  60.579639        1.685265    0.0        0.0
# 17        LINC02672  60.355137        3.767315    0.0        0.0
# 18            TMED9  59.727814        2.088633    0.0        0.0
# 19            RACK1  59.691933        1.911101    0.0        0.0

# %%
sc.pl.rank_genes_groups(adata_ct_results_ncrna["Epithelial"], n_genes=20, show=True)

# %%
deg_results_ncrna["CD8Tex"].head(20)
# Out:
#       names     scores  logfoldchanges          pvals      pvals_adj
# 0    IFI44L  28.369076        3.481000  4.869617e-177  1.159237e-172
# 1      RBPJ  26.238163        1.977415  9.756235e-152  1.548347e-147
# 2     IFI44  25.241953        2.642851  1.388122e-140  1.652247e-136
# 3    SRGAP3  24.229223        2.208002  1.095055e-129  6.517081e-126
# 4       MX1  22.685221        2.146017  6.269133e-114  2.984797e-110
# 5      FUT8  22.466301        1.642953  8.867514e-112  3.838102e-108
# 6    EPSTI1  21.612370        1.798641  1.374145e-103  4.089027e-100
# 7     ISG15  20.878523        2.013364   8.394649e-97   2.103567e-93
# 8    FNDC3B  20.774775        1.491387   7.320552e-96   1.742694e-92
# 9      PVT1  20.126822        1.634804   4.296930e-90   8.894832e-87
# 10  SIPA1L1  20.118055        1.414217   5.127988e-90   1.017286e-86
# 11  EIF2AK2  20.000795        1.535918   5.420022e-89   9.925103e-86
# 12   PLSCR1  19.962719        1.809172   1.162132e-88   2.049269e-85
# 13    FKBP5  19.416456        1.040887   5.602547e-84   9.526531e-81
# 14     XAF1  19.158325        1.612106   8.248550e-82   1.266844e-78
# 15  SPATS2L  19.093023        1.911423   2.885708e-81   4.293483e-78
# 16    IFI27  19.026232        4.021282   1.034296e-80   1.492239e-77
# 17     MAP4  18.997158        1.271566   1.800344e-80   2.521063e-77
# 18    DDX60  18.900175        1.746523   1.136749e-79   1.503381e-76
# 19   PARP14  18.876926        1.224721   1.765671e-79   2.272037e-76

# %%
sc.pl.rank_genes_groups(adata_ct_results_ncrna["CD8Tex"], n_genes=20, show=True)

# %%
deg_results_ncrna["Mono/Macro"].head(20)
# Out:
#        names     scores  logfoldchanges          pvals      pvals_adj
# 0       SPP1  26.729906        4.271660  2.114749e-157  5.034267e-153
# 1       ENO1  26.176958        1.724671  4.862959e-151  5.788259e-147
# 2       TPI1  25.019442        1.711159  3.756482e-138  2.554998e-134
# 3        PKM  24.738775        1.506621  4.094655e-135  2.166118e-131
# 4       LDHA  23.977011        1.882894  4.831528e-127  2.300339e-123
# 5      GAPDH  23.735752        1.544192  1.541978e-124  6.674103e-121
# 6      ADAM8  21.381660        1.920670  1.979558e-101   4.960461e-98
# 7        VIM  21.122974        1.222959   4.891600e-99   1.164470e-95
# 8       CAPG  20.974531        1.345791   1.120664e-97   2.425269e-94
# 9       ST14  20.873760        1.758649   9.274480e-97   1.839864e-93
# 10    RPL37A  20.597296        1.203302   2.902050e-94   5.526780e-91
# 11     IL4I1  20.114563        2.110259   5.502273e-90   9.033404e-87
# 12   ALOX5AP  19.670496        1.743717   3.859875e-86   5.742890e-83
# 13  C15orf48  19.663202        1.849105   4.456884e-86   6.430203e-83
# 14     BCAT1  19.506336        1.515577   9.698839e-85   1.319347e-81
# 15   SLC16A3  19.433748        1.194947   4.000503e-84   5.290777e-81
# 16    SNHG32  19.417450        1.541529   5.495211e-84   7.071149e-81
# 17    SLC1A3  19.067114        1.856276   4.737436e-81   5.370335e-78
# 18   LNCAROD  19.046516        2.071275   7.022348e-81   7.775372e-78
# 19    TMEM51  18.873915        1.466289   1.869227e-79   1.893527e-76

# %%
sc.pl.rank_genes_groups(adata_ct_results_ncrna["Mono/Macro"], n_genes=20, show=True)

# %%
# QUITAR ESTO
adata_tmp_coding = adata_coding.copy()

print(adata_tmp_coding)
print(adata_tmp_coding.obs["Condition"].value_counts())

sc.tl.rank_genes_groups(
    adata_tmp_coding,
    groupby="Condition",
    method="wilcoxon"
)

sc.pl.rank_genes_groups(
    adata_tmp_coding,
    n_genes=20
)
# Out:
# AnnData object with n_obs × n_vars = 43570 × 30795
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Condition
# omt        26166
# tumor      12460
# control     4944
# Name: count, dtype: int64

# %%
# QUITAR ESTO


adata_tmp_ncrna = adata_ncrna.copy()


print(adata_tmp_ncrna)
print(adata_tmp_ncrna.obs["Condition"].value_counts())

sc.tl.rank_genes_groups(
    adata_tmp_ncrna,
    groupby="Condition",
    method="wilcoxon"
)

sc.pl.rank_genes_groups(
    adata_tmp_ncrna,
    n_genes=20
)
# Out:
# AnnData object with n_obs × n_vars = 39966 × 47611
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'
# Condition
# omt        24639
# tumor      10599
# control     4728
# Name: count, dtype: int64

# %%
# ESTO ES CON TODAS LAS POBLACIONES CELULARES-->PREGUNTAR A RODRIGO SI QUITAR ESTO O NO
sc.tl.rank_genes_groups(
    adata_coding_common,
    groupby="Condition",
    method="wilcoxon"
)

deg_coding_all_cellTypes = sc.get.rank_genes_groups_df(
    adata_coding_common,
    group="tumor"
)

deg_coding_all_cellTypes.head()
# Out:
#     names     scores  logfoldchanges  pvals  pvals_adj
# 0    MUC1  90.172539        3.360719    0.0        0.0
# 1   MEIS2  89.335564        4.724521    0.0        0.0
# 2    PTK2  86.809708        2.614120    0.0        0.0
# 3  CDKN2A  85.383415        3.634601    0.0        0.0
# 4    RHEX  85.062149        3.714161    0.0        0.0

# %%
# ESTO ES CON TODAS LAS POBLACIONES CELULARES-->PREGUNTAR A RODRIGO SI QUITAR ESTO O NO
sc.tl.rank_genes_groups(
    adata_ncrna_common,
    groupby="Condition",
    method="wilcoxon"
)

deg_ncrna_all_cellTypes = sc.get.rank_genes_groups_df(
    adata_ncrna_common,
    group="tumor"
)

deg_ncrna_all_cellTypes.head()
# Out:
#      names     scores  logfoldchanges  pvals  pvals_adj
# 0    MEIS2  89.291832        4.687924    0.0        0.0
# 1     PTK2  87.009712        2.591385    0.0        0.0
# 2  MT-RNR1  85.893982        1.478959    0.0        0.0
# 3   CDKN2A  85.207474        3.612665    0.0        0.0
# 4     RHEX  84.313995        3.767326    0.0        0.0

# %% [markdown]
# ## Comparación de genes diferenciales
#
# Comparar posteriormente los DEGs obtenidos en ambos objetos.

# %%
# ESTO ESO CON LAS CÉLULAS COMUNES
genes_a = set(deg_coding_all_cellTypes["names"].head(200))

# sustituir por resultados equivalentes
genes_b = set(deg_ncrna_all_cellTypes["names"].head(200))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %%
# ESTO ESO CON SOLO EPITHELIAL
genes_a = set(deg_results_coding["Epithelial"]["names"].head(200))

# sustituir por resultados equivalentes
genes_b = set(deg_results_ncrna["Epithelial"]["names"].head(200))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %%
# ESTO ESO CON SOLO CD8Tex
genes_a = set(deg_results_coding["CD8Tex"]["names"].head(200))

# sustituir por resultados equivalentes
genes_b = set(deg_results_ncrna["CD8Tex"]["names"].head(200))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %%
# ESTO ESO CON SOLO Mono/Macro
genes_a = set(deg_results_coding["Mono/Macro"]["names"].head(200))

# sustituir por resultados equivalentes
genes_b = set(deg_results_ncrna["Mono/Macro"]["names"].head(200))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %%
# ESTO ESO CON LAS CÉLULAS COMUNES
genes_a = set(deg_coding_all_cellTypes["names"].head(500))

# sustituir por resultados equivalentes
genes_b = set(deg_ncrna_all_cellTypes["names"].head(500))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %%
# ESTO ESO CON LAS CÉLULAS COMUNES
genes_a = set(deg_coding_all_cellTypes["names"].head(1000))

# sustituir por resultados equivalentes
genes_b = set(deg_ncrna_all_cellTypes["names"].head(1000))

venn2(
    [genes_a, genes_b],
    set_labels=("Coding", "Coding+ncRNA")
)

plt.show()

# %% [markdown]
# # Ensayo 2. Enriquecimiento funcional
#
# ## Objetivo
#
# Identificar procesos biológicos alterados.

# %%
gene_list_coding = deg_coding_all_cellTypes["names"].head(300).tolist()

enr_coding = gp.enrichr(
    gene_list=gene_list_coding,
    gene_sets=[
        "GO_Biological_Process_2023",
        "Reactome_2022",
        "KEGG_2021_Human"
    ],
    organism="human",
    outdir=None
)

enr_coding.results.head()
# Out:
#                      Gene_set  \
# 0  GO_Biological_Process_2023
# 1  GO_Biological_Process_2023
# 2  GO_Biological_Process_2023
# 3  GO_Biological_Process_2023
# 4  GO_Biological_Process_2023
#
#                                                 Term Overlap       P-value  \
# 0      Aerobic Electron Transport Chain (GO:0019646)   10/68  6.695290e-08
# 1  Mitochondrial ATP Synthesis Coupled Electron T...   10/70  8.896780e-08
# 2    Maintenance Of Blood-Brain Barrier (GO:0035633)    7/29  1.873556e-07
# 3                  Cellular Respiration (GO:0045333)   10/85  5.756369e-07
# 4  Regulation Of Blood-Brain Barrier Permeability...     4/6  7.269088e-07
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000080            0                     0   11.677765
# 1          0.000080            0                     0   11.287356
# 2          0.000112            0                     0   21.369221
# 3          0.000257            0                     0    9.022989
# 4          0.000260            0                     0  133.094595
#
#    Combined Score                                              Genes
# 0      192.908222  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6A1;...
# 1      183.250132  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6A1;...
# 2      331.014737                TJP1;OCLN;CLDN3;LSR;LAMC1;F11R;TJP2
# 3      129.640393  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6A1;...
# 4     1881.220857                               TJP1;OCLN;TJP2;VEGFA

# %%
gene_list_ncrna = deg_ncrna_all_cellTypes["names"].head(300).tolist()

enr_ncrna = gp.enrichr(
    gene_list=gene_list_ncrna,
    gene_sets=[
        "GO_Biological_Process_2023",
        "Reactome_2022",
        "KEGG_2021_Human"
    ],
    organism="human",
    outdir=None
)

enr_ncrna.results.head()
# Out:
#                      Gene_set  \
# 0  GO_Biological_Process_2023
# 1  GO_Biological_Process_2023
# 2  GO_Biological_Process_2023
# 3  GO_Biological_Process_2023
# 4  GO_Biological_Process_2023
#
#                                                 Term Overlap       P-value  \
# 0      Aerobic Electron Transport Chain (GO:0019646)    9/68  7.738218e-07
# 1  Mitochondrial ATP Synthesis Coupled Electron T...    9/70  9.947660e-07
# 2    Central Nervous System Development (GO:0007417)  17/283  1.435046e-06
# 3             Oxidative Phosphorylation (GO:0006119)    8/63  4.419694e-06
# 4                  Cellular Respiration (GO:0045333)    9/85  5.174650e-06
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000858            0                     0   10.295824
# 1          0.000858            0                     0    9.957242
# 2          0.000858            0                     0    4.388772
# 3          0.001856            0                     0    9.785803
# 4          0.001856            0                     0    7.985893
#
#    Combined Score                                              Genes
# 0      144.882054  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6C;U...
# 1      137.616633  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6C;U...
# 2       59.047918  NCKAP1;ZFHX3;GSTP1;LSR;SMARCA1;MACROH2A2;GRHL2...
# 3      120.653474  NDUFB9;NDUFA8;ATP5F1B;NDUFS5;UQCRC1;ATP5F1C;UQ...
# 4       97.202199  NDUFB9;NDUFA8;UQCRQ;NDUFS5;UQCRC1;CYC1;COX6C;U...

# %%
top = enr_coding.results.head(20)

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=top,
    x="Combined Score",
    y="Term"
)

plt.tight_layout()
plt.show()

# %%
top = enr_ncrna.results.head(20)

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=top,
    x="Combined Score",
    y="Term"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ensayo 3. Actividad de vías mediante PROGENy
#
# ## Objetivo
#
# Inferir actividad funcional de rutas de señalización.

# %%
progeny = dc.op.progeny(
    organism="human",
    top=500
)

progeny.head()
# Out:
#      source   target     weight          padj
# 0  Androgen  TMPRSS2  11.490631  2.384806e-47
# 1  Androgen   NKX3-1  10.622551  2.205102e-44
# 2  Androgen   MBOAT2  10.472733  4.632376e-44
# 3  Androgen     KLK2  10.176186  1.944410e-40
# 4  Androgen     SARG  11.386852  2.790210e-40

# %%
adata_tmp_coding = adata_coding_common.copy()
adata_tmp_ncrna = adata_ncrna_common.copy()

# %%
# QUITAR ESTO?

adata_tmp_coding=adata_coding.copy()
adata_tmp_ncrna=adata_ncrna.copy()

# %%
progeny_genes = progeny["target"].unique()
common_genes_coding = adata_tmp_coding.var_names.intersection(progeny_genes)

print("Genes PROGENy encontrados en adata_tmp_coding:", len(common_genes_coding))

adata_coding_progeny = adata_tmp_coding[:, common_genes_coding].copy()

print(adata_coding_progeny)
# Out:
# Genes PROGENy encontrados en adata_tmp_coding: 5049
# AnnData object with n_obs × n_vars = 39823 × 5049
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
# QUITAR ESTO?

progeny_genes = progeny["target"].unique()
common_genes_coding = adata_tmp_coding.var_names.intersection(progeny_genes)

print("Genes PROGENy encontrados en adata_tmp_coding:", len(common_genes_coding))

adata_coding_progeny = adata_tmp_coding[:, common_genes_coding].copy()

print(adata_coding_progeny)
# Out:
# Genes PROGENy encontrados en adata_tmp_coding: 5049
# AnnData object with n_obs × n_vars = 43570 × 5049
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
progeny_genes = progeny["target"].unique()
common_genes_ncrna = adata_tmp_ncrna.var_names.intersection(progeny_genes)

print("Genes PROGENy encontrados en adata_tmp_ncrna:", len(common_genes_ncrna))

adata_ncrna_progeny = adata_tmp_ncrna[:, common_genes_ncrna].copy()

print(adata_ncrna_progeny)
# Out:
# Genes PROGENy encontrados en adata_tmp_ncrna: 5042
# AnnData object with n_obs × n_vars = 39823 × 5042
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
# QUITAR ESTO?

progeny_genes = progeny["target"].unique()
common_genes_ncrna = adata_tmp_ncrna.var_names.intersection(progeny_genes)

print("Genes PROGENy encontrados en adata_tmp_ncrna:", len(common_genes_ncrna))

adata_ncrna_progeny = adata_tmp_ncrna[:, common_genes_ncrna].copy()

print(adata_ncrna_progeny)
# Out:
# Genes PROGENy encontrados en adata_tmp_ncrna: 5042
# AnnData object with n_obs × n_vars = 39966 × 5042
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Condition', 'DoubletClass', 'DoubletScore', 'Outlier', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'S_score', 'G2M_score', 'phase', 'preannotation', 'preannotation_score', 'leiden_combat_0_5', 'leiden_final', 'annotation', 'annotation_score'
#     var: 'n_cells', 'highly_variable'
#     uns: 'Condition_colors', 'Sample_colors', 'annotation_colors', 'leiden_combat_0_5', 'leiden_final_colors', 'log1p', 'neighbors', 'pca', 'preannotation_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_combat', 'X_umap'
#     varm: 'PCs'
#     layers: 'combat', 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
res_coding = dc.mt.mlm(
    data=adata_coding_progeny,
    net=progeny,
    verbose=True
)
# Out:
# 2026-06-18 18:52:48 | [INFO] mlm - Running mlm
# 2026-06-18 18:52:48 | [INFO] Extracted omics mat with 39823 rows (observations) and 5049 columns (features)
# 2026-06-18 18:52:48 | [INFO] Network adjacency matrix has 5049 unique features and 14 unique sources
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-18 18:52:50 | [INFO] mlm - fitting 14 multivariate models of 5049 observations with 5034 degrees of freedom
# 2026-06-18 18:53:00 | [INFO] mlm - done

# %%
res_ncrna = dc.mt.mlm(
    data=adata_ncrna_progeny,
    net=progeny,
    verbose=True
)
# Out:
# 2026-06-18 18:53:00 | [INFO] mlm - Running mlm
# 2026-06-18 18:53:00 | [INFO] Extracted omics mat with 39823 rows (observations) and 5042 columns (features)
# 2026-06-18 18:53:00 | [INFO] Network adjacency matrix has 5042 unique features and 14 unique sources
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-18 18:53:01 | [INFO] mlm - fitting 14 multivariate models of 5042 observations with 5027 degrees of freedom
# 2026-06-18 18:53:11 | [INFO] mlm - done

# %%
print(adata_coding_progeny.obsm.keys())
# Out:
# KeysView(AxisArrays with keys: X_pca, X_pca_combat, X_umap, score_mlm, padj_mlm)

# %%
print(adata_ncrna_progeny.obsm.keys())
# Out:
# KeysView(AxisArrays with keys: X_pca, X_pca_combat, X_umap, score_mlm, padj_mlm)

# %%
acts_coding = adata_coding_progeny.copy()

acts_coding.obsm["score_mlm"]
# Out:
#                                      Androgen      EGFR  Estrogen   Hypoxia  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.222178  2.890492 -0.712624  0.323298
# CCCTCTCAGCCTATTG-GSM5514787_control  1.349997 -1.258882 -1.523058  1.948762
# GCAACCGGTGCACATT-GSM5514787_control -0.598134 -1.950402 -2.391307  0.615133
# ATCGTGAGTGGAAATT-GSM5514787_control -0.019679  0.992187 -1.163669 -0.023675
# ATGAGGGAGGATTCCT-GSM5514787_control  0.012132  2.173104 -1.267029  1.115449
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.443918 -0.153885  0.565013  6.006804
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.593442  3.224762 -1.126269  5.567993
# TTGCATTCATACCATG-GSM5514794_tumor   -0.942996  1.893345 -1.557701  4.559469
# TTCTCTCCACGACAGA-GSM5514794_tumor    0.213202  1.423943 -0.959424  2.195197
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -0.004374  0.118514 -0.746400  9.161306
#
#                                      JAK-STAT      MAPK      NFkB      PI3K  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  2.663087 -2.241295 -3.922711  1.010037
# CCCTCTCAGCCTATTG-GSM5514787_control  2.143279 -1.936956  0.336029  0.004909
# GCAACCGGTGCACATT-GSM5514787_control -1.066425 -4.330338 -1.705646 -1.023978
# ATCGTGAGTGGAAATT-GSM5514787_control  3.791354  1.059416 -1.688563  1.827294
# ATGAGGGAGGATTCCT-GSM5514787_control  2.123670 -0.710058  0.231079  1.714825
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.333717 -0.434742 -0.697338 -1.686647
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.450003 -4.210026 -0.440821 -2.616782
# TTGCATTCATACCATG-GSM5514794_tumor    0.603568 -2.445507 -2.776583 -1.533087
# TTCTCTCCACGACAGA-GSM5514794_tumor    1.500816 -2.303527 -1.399827 -1.736917
# GGTTCTCCAATCCAGT-GSM5514794_tumor    2.921987 -1.441796 -2.410971 -1.880390
#
#                                          TGFb      TNFa     Trail      VEGF  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control -2.443568  2.934585 -0.936293 -0.895667
# CCCTCTCAGCCTATTG-GSM5514787_control -1.653234  0.339660 -1.535148  0.571054
# GCAACCGGTGCACATT-GSM5514787_control -2.307665 -0.197916 -4.460503 -1.381975
# ATCGTGAGTGGAAATT-GSM5514787_control -2.946776  1.976714 -1.119957  0.664302
# ATGAGGGAGGATTCCT-GSM5514787_control -2.604062  1.377777 -1.372688  0.093669
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -1.158379  3.866191 -0.214570 -0.576904
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.710730  0.576418  0.573363 -0.488358
# TTGCATTCATACCATG-GSM5514794_tumor   -0.904305  2.933299  0.623239 -0.476604
# TTCTCTCCACGACAGA-GSM5514794_tumor   -0.677097  1.034169  0.873605 -0.010588
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -0.230142  1.792868  1.335865 -0.454399
#
#                                           WNT       p53
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.320448 -7.153328
# CCCTCTCAGCCTATTG-GSM5514787_control -0.685757 -5.966498
# GCAACCGGTGCACATT-GSM5514787_control -1.972691 -6.966290
# ATCGTGAGTGGAAATT-GSM5514787_control -0.099658 -8.574778
# ATGAGGGAGGATTCCT-GSM5514787_control -0.159038 -9.576758
# ...                                       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.263730 -0.772897
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.819475  0.762624
# TTGCATTCATACCATG-GSM5514794_tumor   -1.011836 -9.162120
# TTCTCTCCACGACAGA-GSM5514794_tumor   -0.235358  0.164447
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -1.404100 -0.047650
#
# [39823 rows x 14 columns]

# %%
acts_ncrna = adata_ncrna_progeny.copy()

acts_ncrna.obsm["score_mlm"]
# Out:
#                                      Androgen      EGFR  Estrogen   Hypoxia  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.374561  2.648733 -0.773496  0.348669
# CCCTCTCAGCCTATTG-GSM5514787_control  1.383278 -1.239923 -1.605230  2.073115
# GCAACCGGTGCACATT-GSM5514787_control -0.544026 -1.898832 -2.133467  0.331559
# ATCGTGAGTGGAAATT-GSM5514787_control -0.194041  0.780963 -1.188309 -0.273961
# ATGAGGGAGGATTCCT-GSM5514787_control  0.104689  1.959020 -1.141488  0.963691
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.440334 -0.298252  0.560771  5.848205
# ATGAGTCCAGATACTC-GSM5514794_tumor    0.862385  3.015275 -1.555712  5.078022
# TTGCATTCATACCATG-GSM5514794_tumor   -0.518277  1.559894 -1.348508  4.529012
# TTCTCTCCACGACAGA-GSM5514794_tumor   -0.589644  1.347314 -0.656798  0.399963
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -0.716914 -0.065378 -0.526954  7.277247
#
#                                      JAK-STAT      MAPK      NFkB      PI3K  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  2.311452 -1.681686 -3.862424  1.077763
# CCCTCTCAGCCTATTG-GSM5514787_control  2.013418 -1.662598  0.653638  0.085496
# GCAACCGGTGCACATT-GSM5514787_control -1.265715 -3.941944 -1.555044 -1.246247
# ATCGTGAGTGGAAATT-GSM5514787_control  3.680166  1.514589 -1.567085  1.736215
# ATGAGGGAGGATTCCT-GSM5514787_control  1.934265 -0.065803  0.443161  1.239038
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -1.015790 -0.174170 -0.498088 -1.327384
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.373467 -3.566719 -0.656418 -1.710826
# TTGCATTCATACCATG-GSM5514794_tumor    0.467478 -1.831705 -2.404561 -1.228733
# TTCTCTCCACGACAGA-GSM5514794_tumor    1.348380 -1.603381 -1.279225 -1.435885
# GGTTCTCCAATCCAGT-GSM5514794_tumor    3.222061 -1.334045 -2.507205 -1.818116
#
#                                          TGFb      TNFa     Trail      VEGF  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control -2.469148  3.176781 -0.668136 -0.788379
# CCCTCTCAGCCTATTG-GSM5514787_control -1.540695  0.254276 -1.550443  0.942474
# GCAACCGGTGCACATT-GSM5514787_control -2.250963 -0.177423 -4.711249 -0.896967
# ATCGTGAGTGGAAATT-GSM5514787_control -2.910257  2.091684 -1.052720  0.906674
# ATGAGGGAGGATTCCT-GSM5514787_control -2.647262  1.429973 -1.334585  0.336419
# ...                                       ...       ...       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.897798  3.802882 -0.445406 -1.668214
# ATGAGTCCAGATACTC-GSM5514794_tumor   -0.797618  0.698113  0.532195 -0.507491
# TTGCATTCATACCATG-GSM5514794_tumor   -0.661285  2.600799  0.819430 -0.496210
# TTCTCTCCACGACAGA-GSM5514794_tumor   -0.619282  0.956311  0.255866 -0.180790
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -0.100697  1.995473  1.456455 -0.498172
#
#                                           WNT       p53
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.342110 -7.026588
# CCCTCTCAGCCTATTG-GSM5514787_control -0.695772 -5.873926
# GCAACCGGTGCACATT-GSM5514787_control -1.800346 -6.723110
# ATCGTGAGTGGAAATT-GSM5514787_control  0.121592 -8.751402
# ATGAGGGAGGATTCCT-GSM5514787_control -0.210209 -9.691653
# ...                                       ...       ...
# CGGGTGTGTGTACAGG-GSM5514794_tumor   -0.257805 -0.386983
# ATGAGTCCAGATACTC-GSM5514794_tumor   -1.305571  0.752383
# TTGCATTCATACCATG-GSM5514794_tumor   -1.553548 -8.944321
# TTCTCTCCACGACAGA-GSM5514794_tumor   -0.395435  0.062039
# GGTTCTCCAATCCAGT-GSM5514794_tumor   -1.430352  0.113660
#
# [39823 rows x 14 columns]

# %%
scores_mlm_coding = adata_coding_progeny.obsm["score_mlm"].copy()

scores_mlm_coding["Condition"] = adata_coding_progeny.obs["Condition"].values

scores_mlm_coding.head()
# Out:
#                                      Androgen      EGFR  Estrogen   Hypoxia  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.222178  2.890492 -0.712624  0.323298
# CCCTCTCAGCCTATTG-GSM5514787_control  1.349997 -1.258882 -1.523058  1.948762
# GCAACCGGTGCACATT-GSM5514787_control -0.598134 -1.950402 -2.391307  0.615133
# ATCGTGAGTGGAAATT-GSM5514787_control -0.019679  0.992187 -1.163669 -0.023675
# ATGAGGGAGGATTCCT-GSM5514787_control  0.012132  2.173104 -1.267029  1.115449
#
#                                      JAK-STAT      MAPK      NFkB      PI3K  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  2.663087 -2.241295 -3.922711  1.010037
# CCCTCTCAGCCTATTG-GSM5514787_control  2.143279 -1.936956  0.336029  0.004909
# GCAACCGGTGCACATT-GSM5514787_control -1.066425 -4.330338 -1.705646 -1.023978
# ATCGTGAGTGGAAATT-GSM5514787_control  3.791354  1.059416 -1.688563  1.827294
# ATGAGGGAGGATTCCT-GSM5514787_control  2.123670 -0.710058  0.231079  1.714825
#
#                                          TGFb      TNFa     Trail      VEGF  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control -2.443568  2.934585 -0.936293 -0.895667
# CCCTCTCAGCCTATTG-GSM5514787_control -1.653234  0.339660 -1.535148  0.571054
# GCAACCGGTGCACATT-GSM5514787_control -2.307665 -0.197916 -4.460503 -1.381975
# ATCGTGAGTGGAAATT-GSM5514787_control -2.946776  1.976714 -1.119957  0.664302
# ATGAGGGAGGATTCCT-GSM5514787_control -2.604062  1.377777 -1.372688  0.093669
#
#                                           WNT       p53 Condition
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.320448 -7.153328   control
# CCCTCTCAGCCTATTG-GSM5514787_control -0.685757 -5.966498   control
# GCAACCGGTGCACATT-GSM5514787_control -1.972691 -6.966290   control
# ATCGTGAGTGGAAATT-GSM5514787_control -0.099658 -8.574778   control
# ATGAGGGAGGATTCCT-GSM5514787_control -0.159038 -9.576758   control

# %%
scores_mlm_ncrna = adata_ncrna_progeny.obsm["score_mlm"].copy()

scores_mlm_ncrna["Condition"] = adata_ncrna_progeny.obs["Condition"].values

scores_mlm_ncrna.head()
# Out:
#                                      Androgen      EGFR  Estrogen   Hypoxia  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.374561  2.648733 -0.773496  0.348669
# CCCTCTCAGCCTATTG-GSM5514787_control  1.383278 -1.239923 -1.605230  2.073115
# GCAACCGGTGCACATT-GSM5514787_control -0.544026 -1.898832 -2.133467  0.331559
# ATCGTGAGTGGAAATT-GSM5514787_control -0.194041  0.780963 -1.188309 -0.273961
# ATGAGGGAGGATTCCT-GSM5514787_control  0.104689  1.959020 -1.141488  0.963691
#
#                                      JAK-STAT      MAPK      NFkB      PI3K  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  2.311452 -1.681686 -3.862424  1.077763
# CCCTCTCAGCCTATTG-GSM5514787_control  2.013418 -1.662598  0.653638  0.085496
# GCAACCGGTGCACATT-GSM5514787_control -1.265715 -3.941944 -1.555044 -1.246247
# ATCGTGAGTGGAAATT-GSM5514787_control  3.680166  1.514589 -1.567085  1.736215
# ATGAGGGAGGATTCCT-GSM5514787_control  1.934265 -0.065803  0.443161  1.239038
#
#                                          TGFb      TNFa     Trail      VEGF  \
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control -2.469148  3.176781 -0.668136 -0.788379
# CCCTCTCAGCCTATTG-GSM5514787_control -1.540695  0.254276 -1.550443  0.942474
# GCAACCGGTGCACATT-GSM5514787_control -2.250963 -0.177423 -4.711249 -0.896967
# ATCGTGAGTGGAAATT-GSM5514787_control -2.910257  2.091684 -1.052720  0.906674
# ATGAGGGAGGATTCCT-GSM5514787_control -2.647262  1.429973 -1.334585  0.336419
#
#                                           WNT       p53 Condition
# barcode
# ATCGTAGGTAGTGTGG-GSM5514787_control  0.342110 -7.026588   control
# CCCTCTCAGCCTATTG-GSM5514787_control -0.695772 -5.873926   control
# GCAACCGGTGCACATT-GSM5514787_control -1.800346 -6.723110   control
# ATCGTGAGTGGAAATT-GSM5514787_control  0.121592 -8.751402   control
# ATGAGGGAGGATTCCT-GSM5514787_control -0.210209 -9.691653   control

# %%
mean_scores_by_condition_coding = scores_mlm_coding.groupby("Condition").mean()

mean_scores_by_condition_coding
# Out:
# /tmp/ipykernel_2707/3088482306.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_scores_by_condition_coding = scores_mlm_coding.groupby("Condition").mean()
#            Androgen      EGFR  Estrogen   Hypoxia  JAK-STAT      MAPK  \
# Condition
# control    0.355015 -0.049475 -0.966066  1.205240  1.950843 -1.850742
# omt        0.478172 -0.836513 -0.805915  1.738926  1.336201 -0.805820
# tumor      0.103436 -1.403990 -1.062105  1.856268  2.079856 -1.434354
#
#                NFkB      PI3K      TGFb      TNFa     Trail      VEGF  \
# Condition
# control   -0.274002 -0.528193 -1.271330  0.816706 -0.507574  0.123726
# omt        0.906132  0.636924 -0.355113 -0.220436 -1.404723  0.426053
# tumor     -1.636429  1.097812 -1.095410  0.871386 -2.841621 -0.143908
#
#                 WNT       p53
# Condition
# control   -0.169873 -5.143544
# omt       -0.717674 -6.577056
# tumor     -1.394302 -7.614178

# %%
mean_scores_by_condition_ncrna = scores_mlm_ncrna.groupby("Condition").mean()

mean_scores_by_condition_ncrna
# Out:
# /tmp/ipykernel_2707/2925531589.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_scores_by_condition_ncrna = scores_mlm_ncrna.groupby("Condition").mean()
#            Androgen      EGFR  Estrogen   Hypoxia  JAK-STAT      MAPK  \
# Condition
# control    0.390070 -0.155603 -0.966157  1.225487  1.906753 -1.525727
# omt        0.556031 -0.843281 -0.861532  1.781386  1.358788 -0.578255
# tumor      0.190050 -1.405432 -1.040919  1.679664  2.058413 -1.149650
#
#                NFkB      PI3K      TGFb      TNFa     Trail      VEGF  \
# Condition
# control   -0.141271 -0.528263 -1.234019  0.842084 -0.515397  0.266361
# omt        1.009453  0.637447 -0.308142 -0.178028 -1.432536  0.510880
# tumor     -1.566261  1.074473 -1.036078  0.904488 -2.894003 -0.032074
#
#                 WNT       p53
# Condition
# control   -0.180275 -5.055080
# omt       -0.755064 -6.496088
# tumor     -1.468386 -7.484408

# %%
plt.figure(figsize=(8, 5))

sns.heatmap(
    mean_scores_by_condition_coding,
    cmap="vlag",
    center=0,
    annot=True
)

plt.title("Mean PROGENy pathway activity in Coding")
plt.xlabel("Pathway")
plt.ylabel("Condition")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.heatmap(
    mean_scores_by_condition_ncrna,
    cmap="vlag",
    center=0,
    annot=True
)

plt.title("Mean PROGENy pathway activity in Non coding")
plt.xlabel("Pathway")
plt.ylabel("Condition")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ensayo 4. ncRNAs y pri-miRNAs
#
# ## Objetivo
#
# Identificar genes no codificantes potencialmente implicados en cáncer de ovario.

# %%
var = adata_ncrna.var.copy()

var.head()
# Out:
#                            n_cells  highly_variable
# 5S-rRNA-ENSG00000277411.1       92            False
# 5S-rRNA-ENSG00000285626.1       83            False
# A1BG                            55            False
# A1BG-AS1                      2705            False
# A1CF                           115            False

# %% [markdown]
# ## Filtrado de ncRNAs
#
# Adaptar según la anotación disponible.

# %%
ncrna_genes = adata_ncrna.var_names[
    adata_ncrna.var_names.str.contains(
        "MIR|Mir|LINC|lnc",
        regex=True
    )
]

len(ncrna_genes)
# Out:
# 2012

# %%
sc.pl.dotplot(
    adata_ncrna,
    var_names=ncrna_genes[:20],
    groupby="annotation"
)

# %%
sc.pl.heatmap(
    adata_ncrna,
    var_names=ncrna_genes[:20],
    groupby="annotation"
)

# %% [markdown]
# # Resumen final
#
# El estudiante deberá resumir:
#
# 1. Qué genes cambian.
# 2. Qué procesos biológicos cambian.
# 3. Qué vías están activadas.
# 4. Qué ncRNAs aportan información adicional.
#
# Comparar siempre los resultados obtenidos en:
#
# - Coding-only.
# - Coding + ncRNA.
